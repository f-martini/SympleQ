# %%
from scripts.experiments.symmetries import clifford_symmetry
from sympleq.models.random_hamiltonian import random_gate_symmetric_hamiltonian
from sympleq.core.circuits import Gate, SWAP, Hadamard

# %% [markdown]
# Simple Example

# %%
n_qubits = 5
n_paulis = 10

sym = SWAP(0, 1, 2)
H = random_gate_symmetric_hamiltonian(sym, n_qubits, n_paulis, scrambled=True)

G_sym = clifford_symmetry(H, phase_correction=False)
# assert G_sym.act(H) == H
# assert G_sym.symplectic != np.eye(2 * n_qubits)

# print('Found non-trivial symmetry!')
